# %% [markdown]
# # Final Project Raw Dataset Update_Sean Fitzgerald

# %% [markdown]
# # Dataset 1-2019 EPA PM 2.5

# %%
print('hello fitz')
# Out:
# hello fitz

# %% [markdown]
# - This is a dataset came from epa.gov
# - You can [download this epa dataset from here](https://www.epa.gov/outdoor-air-quality-data/download-daily-data)
# - This dataset is showing Particulate Matter 2.5 (PM 2.5) from 2019 for Cuyahoga County
# - [Here](https://drive.google.com/file/d/1aBtoO0iSzdmFwRS4sKwiNFFDhzufYOkB/view?usp=sharing) is the link to that dataset csv file for 2019
# - I want to figure out how the particulate matter 2.5 changed from before COVID and apply it to demographics as well to see who was affected most and least.

# %% [markdown]
# # Dataset 2-2020 EPA PM 2.5

# %% [markdown]
#  - This dataset also came from epa.gov
#  - You can [download the 2020 epa dataset from here](https://www.epa.gov/outdoor-air-quality-data/download-daily-data)
#  - This dataset is showing particulate matter 2.5 (PM 2.5) from 2020 for Cuyahoga County
#  - [For 2020, Here](https://drive.google.com/file/d/1p42HQfIbvjSTYj-fvQp35-Km8yWFF2Uo/view?usp=sharing) is the link to the csv file
#  - I want to figure out how the particulate matter 2.5 affected people during COVID and how it's changed from 2019. I also want to apply it to demographics as well to see who was affected most and least.

# %% [markdown]
# # Dataset 3-Demographic Data for Cuyahoga County 2019

# %% [markdown]
# - This dataset came from the US Census Bureau from data.census.gov
# - You can download the datasets from [here](https://data.census.gov/cedsci/)
# - For the 2019 Cuyahoga County Demogrpahic data related to age, race, sex, gender, population, ethnicity, and more, this is the link to the dataset itself [here](https://data.census.gov/cedsci/table?q=race&g=0500000US39035&tid=ACSDP1Y2019.DP05&hidePreview=true)
# - For the [csv file for 2019 demographic data](https://drive.google.com/file/d/1pTodpzWOprDyK6MzaNkbotVkt-hfzce-/view?usp=sharing) this is the link
# - I want to see how the data affected different demographics within the county from the 2019 data and compare it to 2020's data.

# %% [markdown]
# # Other Questions from the data-Collective

# %% [markdown]
# - I want to see the changes in PM 2.5 before and during COVID-19 and see what kind of effect it would have on people based on several demographic factors in Cuyahoga County as insights, and the impacts that air pollution reduction during COVID has had versus before with more air pollution

# %% [markdown]
# # Datasets-Demographics, 2019 epa, 2020 epa

# %%
import pandas as pd

# %%
df = pd.read_csv('acs-2019-us-census.csv')

# %%
df.head(10)
# Out:
#                                   Unnamed: 0 Cuyahoga County, Ohio!!  \
# 0                                      Label                Estimate
# 1                                SEX AND AGE                     NaN
# 2                           Total population               1,235,072
# 3                                       Male                 589,073
# 4                                     Female                 645,999
# 5          Sex ratio (males per 100 females)                    91.2
# 6                              Under 5 years                  69,888
# 7                               5 to 9 years                  64,268
# 8                             10 to 14 years                  76,255
# 9                             15 to 19 years                  72,567
#
#         Unnamed: 2 Unnamed: 3               Unnamed: 4
# 0  Margin of Error    Percent  Percent Margin of Error
# 1              NaN        NaN                      NaN
# ...

# %%
df.tail(10)
# Out:
#                                            Unnamed: 0 Cuyahoga County, Ohio!!  \
# 85              Native Hawaiian and Other Pacific ...                     203
# 86                              Some other race alone                   3,480
# 87                                  Two or more races                  30,456
# 88                  Two races including Some other...                     674
# 89                  Two races excluding Some other...                  29,782
# 90                                Total housing units                 617,202
# 91                     CITIZEN, VOTING AGE POPULATION                     NaN
# 92                    Citizen, 18 and over population                 943,990
# 93                                               Male                 440,583
# 94                                             Female                 503,407
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4
# 85       ±182      0.00%       ±0.1
# 86     ±1,644      0.30%       ±0.1
# ...

# %%
df.shape
# Out:
# (95, 5)

# %%
df = pd.read_csv('epa-2019-data-pm.csv')

# %%
df.head(10)
# Out:
#          Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0  01/03/2019    AQS  390350034    1                             6.4
# 1  01/06/2019    AQS  390350034    1                             3.0
# 2  01/09/2019    AQS  390350034    1                             3.2
# 3  01/12/2019    AQS  390350034    1                             5.9
# 4  01/15/2019    AQS  390350034    1                            20.3
# 5  01/18/2019    AQS  390350034    1                            16.4
# 6  01/21/2019    AQS  390350034    1                             3.7
# 7  01/24/2019    AQS  390350034    1                             5.7
# 8  01/27/2019    AQS  390350034    1                             9.4
# 9  02/01/2019    AQS  390350034    1                            10.6
#
#       UNITS  DAILY_AQI_VALUE   Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0  ug/m3 LC               27  District 6                1             100.0
# ...

# %%
df.tail(10)
# Out:
#             Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 1874  12/05/2019    AQS  390351002    1                             4.9
# 1875  12/06/2019    AQS  390351002    1                             4.9
# 1876  12/08/2019    AQS  390351002    1                             7.6
# 1877  12/11/2019    AQS  390351002    1                             6.8
# 1878  12/14/2019    AQS  390351002    1                            18.5
# 1879  12/17/2019    AQS  390351002    1                             9.4
# 1880  12/20/2019    AQS  390351002    1                            18.4
# 1881  12/23/2019    AQS  390351002    1                             8.0
# 1882  12/26/2019    AQS  390351002    1                             4.5
# 1883  12/29/2019    AQS  390351002    1                             8.1
#
#          UNITS  DAILY_AQI_VALUE  Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 1874  ug/m3 LC               20  Brookpark                1             100.0
# ...

# %%
df.shape
# Out:
# (1884, 20)

# %%
df = pd.read_csv('epa-2020-data-pm.csv')

# %%
df.head(10)
# Out:
#          Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0  01/01/2020    AQS  390350034    1                             6.5
# 1  01/04/2020    AQS  390350034    1                             6.7
# 2  01/07/2020    AQS  390350034    1                             6.2
# 3  01/10/2020    AQS  390350034    1                             4.4
# 4  01/13/2020    AQS  390350034    1                             5.7
# 5  01/16/2020    AQS  390350034    1                             6.2
# 6  01/19/2020    AQS  390350034    1                            10.7
# 7  01/22/2020    AQS  390350034    1                            13.9
# 8  01/25/2020    AQS  390350034    1                             4.4
# 9  01/28/2020    AQS  390350034    1                             6.4
#
#       UNITS  DAILY_AQI_VALUE   Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0  ug/m3 LC               27  District 6                1             100.0
# ...

# %%
df.tail(10)
# Out:
#             Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 1529  09/21/2020    AQS  390351002    1                             5.0
# 1530  09/24/2020    AQS  390351002    1                            12.3
# 1531  09/27/2020    AQS  390351002    1                             6.1
# 1532  09/30/2020    AQS  390351002    1                             2.7
# 1533  10/03/2020    AQS  390351002    1                             4.4
# 1534  10/06/2020    AQS  390351002    1                             4.3
# 1535  10/09/2020    AQS  390351002    1                             5.7
# 1536  10/12/2020    AQS  390351002    1                             4.0
# 1537  10/15/2020    AQS  390351002    1                             2.6
# 1538  10/18/2020    AQS  390351002    1                             4.8
#
#          UNITS  DAILY_AQI_VALUE  Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 1529  ug/m3 LC               21  Brookpark                1             100.0
# ...

# %%
df.shape
# Out:
# (1539, 20)
